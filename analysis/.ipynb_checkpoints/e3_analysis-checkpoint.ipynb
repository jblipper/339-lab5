# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plt.rcParams.update({'font.size': 16})

# %% [markdown]
# # Set-point temperature: -10C

# %%
paths = ["../data/e3_1_-10_run1.raw",
      "../data/e3_1_-10_run2.raw",
      "../data/e3_1_-10_run3.raw"]

plt.figure(figsize=(12,3))
for path in paths:
    data = np.genfromtxt(path, skip_header=13, delimiter=",")
    plt.plot(data[:,0]-data[0,0], data[:,1])

set_pt_temp = -10
band = 1/2

plt.hlines(set_pt_temp, 0, 280, linestyle="--", colors="gray")
plt.ylabel("Temperature [$^{\circ}$C]")
plt.xlabel("Time [ms]")
plt.ylim(set_pt_temp-band, set_pt_temp+band)
plt.xlim(120, 280)
plt.show()

# %%
# calculating stuff

set_pt_temp = -10
band = 1
ss = np.zeros(len(paths))
stab = np.zeros(len(paths))

for i, path in enumerate(paths):
    data = np.genfromtxt(path, skip_header=13, delimiter=",")
    lim = int(len(data[:,1])/2)
    
    ss[i] = np.mean(data[:,1][lim:])
    
    stab[i] = np.std(data[:,1])**2/len(data[:,1])
    
    

# calculate residual control error and steady state temp
steady_state = np.mean(ss)
print("Steady state temp:", steady_state)
residual_control_error = steady_state - set_pt_temp
print("Residual control error:", residual_control_error, "+-", np.std(ss))

# calculate system stability
stability = np.mean(stab)
print(stability)

# response time
resid = np.abs(data[:,1]-steady_state)
resp = (data[:,0]-data[0,0])[np.where(resid == resid.min())[0][0]]
print(resp)

upper_band_limit = set_pt_temp+band
resid = data[:,1]-upper_band_limit
resp = (data[:,0]-data[0,0])[np.where(resid == resid.min())[0][0]]
print(resp)
# Out:
# Steady state temp: -9.474263833085681
# Residual control error: 0.525736166914319 +- 0.12384007942626832
# 0.10263205594420212
# 137.0
# 141.2

# %%
paths = ["../data/e3_1_-10_run1.raw",
      "../data/e3_1_-10_run2.raw",
      "../data/e3_1_-10_run3.raw"]

plt.figure(figsize=(12,3))
for path in paths:
    data = np.genfromtxt(path, skip_header=13, delimiter=",")
    plt.plot(data[:,0]-data[0,0], data[:,1])

set_pt_temp = -10
band = 1/2

plt.hlines(set_pt_temp, 0, 280, linestyle="--", colors="gray")
plt.vlines(resp, -11, -9)
plt.ylabel("Temperature [$^{\circ}$C]")
plt.xlabel("Time [ms]")
plt.ylim(set_pt_temp-band, set_pt_temp+band)
plt.xlim(120, 280)
plt.show()
